# %%
import pandas as pd

# %%
dataset = pd.read_csv('train_processed.csv')

# %%
dataset.head()
# Out:
#                                              address      lat      lon  \
# 0   Бишкек, Московская - Уметалиева, Московская, 191  42.8711  74.5823
# 1  Бишкек, с. Кок-Джар, с.Кок-Жар, ул.Конкур Осмо...  42.8131  74.6482
# 2                Бишкек, 12 м-н, 12-й микрорайон, 69  42.8129  74.6390
# 3  Бишкек, Магистраль, Байтик Баатыра (недалеко о...  42.8171  74.6059
# 4           Бишкек, Джал 15 м-н, Ахунбаева/Тыналиева  42.8467  74.5656
#
#   offer_type               series building_material  build_year  floor  \
# 0  от агента  индивид. планировка         кирпичный      2017.0   10.0
# 1  от агента               элитка        монолитный      2023.0   10.0
# 2  от агента            106 серия         кирпичный      1990.0    7.0
# 3  от агента               элитка        монолитный      2022.0    6.0
# 4  от агента               элитка        монолитный      2023.0    6.0
#
#    total_floors  rooms  area_total  area_living   condition  usd_price
# ...

# %%
dataset.columns
# Out:
# Index(['address', 'lat', 'lon', 'offer_type', 'series', 'building_material',
#        'build_year', 'floor', 'total_floors', 'rooms', 'area_total',
#        'area_living', 'condition', 'usd_price'],
#       dtype='str')
